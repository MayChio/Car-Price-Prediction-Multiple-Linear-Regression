# %%
#Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# Cargar el dataset
df = pd.read_csv("CarPrice_Assignment.csv")

# 👀 Ver las primeras filas
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Gráfico de dispersión
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='horsepower', y='price')
plt.title('Relación entre Horsepower y Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Variables para regresión
X = df[['horsepower']]  # Variable independiente
y = df['price']         # Variable dependiente

# Crear y entrenar el modelo
modelo = LinearRegression()
modelo.fit(X, y)

# Predicciones
y_pred = modelo.predict(X)

# Resultados del modelo
print("Coeficiente (pendiente):", modelo.coef_[0])
print("Intersección:", modelo.intercept_)
print("R² (score):", modelo.score(X, y))
# Out:
# Coeficiente (pendiente): 163.26306096964797
# Intersección: -3721.7614943227636
# R² (score): 0.653088356490231

# %%
#Gráfica con línea de regresión
plt.figure(figsize=(8,5))
sns.scatterplot(x=X['horsepower'], y=y, label='Datos reales')
plt.plot(X, y_pred, color='red', label='Línea de regresión')
plt.title('Regresión Lineal: Horsepower vs Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='enginesize', y='price')
plt.title('Relación entre Engine Size y Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Regresión lineal
X2 = df[['enginesize']]
y2 = df['price']

modelo2 = LinearRegression()
modelo2.fit(X2, y2)
y2_pred = modelo2.predict(X2)

print("Coeficiente:", modelo2.coef_[0])
print("Intersección:", modelo2.intercept_)
print("R² (score):", modelo2.score(X2, y2))
# Out:
# Coeficiente: 167.69841639317224
# Intersección: -8005.445531145215
# R² (score): 0.7641291357806176

# %%
# Gráfico con línea de regresión
plt.figure(figsize=(8,5))
sns.scatterplot(x=X2['enginesize'], y=y2, label='Datos reales')
plt.plot(X2, y2_pred, color='red', label='Línea de regresión')
plt.title('Regresión Lineal: Engine Size vs Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='curbweight', y='price')
plt.title('Relación entre Curb Weight y Price')
plt.xlabel('Curb Weight')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Regresión lineal
X3 = df[['curbweight']]
y3 = df['price']

modelo3 = LinearRegression()
modelo3.fit(X3, y3)
y3_pred = modelo3.predict(X3)

print("Coeficiente:", modelo3.coef_[0])
print("Intersección:", modelo3.intercept_)
print("R² (score):", modelo3.score(X3, y3))
# Out:
# Coeficiente: 12.816172553003907
# Intersección: -19475.862380320832
# R² (score): 0.6977342414446954

# %%
#  Gráfico con línea de regresión 1 
plt.figure(figsize=(8,5))
sns.scatterplot(x=X3['curbweight'], y=y3, label='Datos reales')
plt.plot(X3, y3_pred, color='red', label='Línea de regresión')
plt.title('Regresión Lineal: Curb Weight vs Price')
plt.xlabel('Curb Weight')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Este cambio es para forzar el push a GitHub

# %%
print("Comparación de R²:")
print("Horsepower vs Price: ", modelo.score(X, y))
print("Engine Size vs Price:", modelo2.score(X2, y2))
print("Curb Weight vs Price:", modelo3.score(X3, y3))
# Out:
# Comparación de R²:
# Horsepower vs Price:  0.653088356490231
# Engine Size vs Price: 0.7641291357806176
# Curb Weight vs Price: 0.6977342414446954
